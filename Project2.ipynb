# %%
import requests
import json
from pprint import pprint

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be'
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'EK', 'icao': 'UAE', 'name': 'Emirates'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tullamarine',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:40:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'MEL',
#                        'icao': 'YMML',
#                        'scheduled': '2021-04-22T08:40:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Australia/Melbourne'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Brisbane International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '19',
#                          'iata': 'BNE',
#                          'icao': 'YBBN',
#                          'scheduled': '2021-04-22T06:15:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Brisbane'},
#            'flight': {'codeshared': {'airline_iata': 'qf',
#                                      'airline_icao': 'qfa',
#                                      'airline_name': 'qantas',
#                                      'flight_iata': 'qf605',
#                                      'flight_icao': 'qfa605',
#                                      'flight_number': '605'},
#                       'iata': 'EK5605',
#                       'icao': 'UAE5605',
#                       'number': '5605'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'JQ', 'icao': 'JST', 'name': 'Jetstar'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Cairns',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'CNS',
#                        'icao': 'YBCS',
#                        'scheduled': '2021-04-22T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Australia/Brisbane'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Brisbane International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:10:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '28',
#                          'iata': 'BNE',
#                          'icao': 'YBBN',
#                          'scheduled': '2021-04-22T06:10:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Brisbane'},
#            'flight': {'codeshared': None,
#                       'iata': 'JQ928',
#                       'icao': 'JST928',
#                       'number': '928'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Dali',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:01:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'DLU',
#                        'icao': 'ZPDL',
#                        'scheduled': '2021-04-22T08:01:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'P',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'tv',
#                                      'airline_icao': 'tba',
#                                      'airline_name': 'tibet airlines',
#                                      'flight_iata': 'tv9915',
#                                      'flight_icao': 'tba9915',
#                                      'flight_number': '9915'},
#                       'iata': 'EU7257',
#                       'icao': 'UEA7257',
#                       'number': '7257'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'QB', 'icao': 'QSM', 'name': 'Qeshm Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Al-Ashraf International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T01:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NJF',
#                        'icao': 'ORNI',
#                        'scheduled': '2021-04-22T01:30:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Baghdad'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Mashad',
#                          'delay': None,
#                          'estimated': '2021-04-22T00:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'MHD',
#                          'icao': 'OIMM',
#                          'scheduled': '2021-04-22T00:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tehran'},
#            'flight': {'codeshared': None,
#                       'iata': 'QB2297',
#                       'icao': 'QSM2297',
#                       'number': '2297'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'QF', 'icao': 'QFA', 'name': 'Qantas'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tullamarine',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T07:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '22',
#                        'iata': 'MEL',
#                        'icao': 'YMML',
#                        'scheduled': '2021-04-22T07:15:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Australia/Melbourne'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hobart',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'HBA',
#                          'icao': 'YMHB',
#                          'scheduled': '2021-04-22T06:00:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Hobart'},
#            'flight': {'codeshared': None,
#                       'iata': 'QF1550',
#                       'icao': 'QFA1550',
#                       'number': '1550'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NZ', 'icao': 'ANZ', 'name': 'Air New Zealand'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tullamarine',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T07:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '22',
#                        'iata': 'MEL',
#                        'icao': 'YMML',
#                        'scheduled': '2021-04-22T07:15:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Australia/Melbourne'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hobart',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'HBA',
#                          'icao': 'YMHB',
#                          'scheduled': '2021-04-22T06:00:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Hobart'},
#            'flight': {'codeshared': {'airline_iata': 'qf',
#                                      'airline_icao': 'qfa',
#                                      'airline_name': 'qantas',
#                                      'flight_iata': 'qf1550',
#                                      'flight_icao': 'qfa1550',
#                                      'flight_number': '1550'},
#                       'iata': 'NZ7361',
#                       'icao': 'ANZ7361',
#                       'number': '7361'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'HT', 'icao': 'HAT', 'name': 'Air Horizont'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Zhengzhou',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T05:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'CGO',
#                        'icao': 'ZHCC',
#                        'scheduled': '2021-04-22T05:25:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nanchang',
#                          'delay': None,
#                          'estimated': '2021-04-22T03:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'KHN',
#                          'icao': 'ZSCN',
#                          'scheduled': '2021-04-22T03:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'HT3810',
#                       'icao': 'HAT3810',
#                       'number': '3810'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CA', 'icao': 'CCA', 'name': 'Air China LTD'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9566',
#                                      'flight_icao': 'csz9566',
#                                      'flight_number': '9566'},
#                       'iata': 'CA3866',
#                       'icao': 'CCA3866',
#                       'number': '3866'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9566',
#                                      'flight_icao': 'csz9566',
#                                      'flight_number': '9566'},
#                       'iata': '3U2648',
#                       'icao': 'CSC2648',
#                       'number': '2648'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'ZH',
#                        'icao': 'CSZ',
#                        'name': 'Shenzhen Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'ZH9473',
#                       'icao': 'CSZ9473',
#                       'number': '9473'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'SC',
#                        'icao': 'CDG',
#                        'name': 'Shandong Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': 'SC9123',
#                       'icao': 'CDG9123',
#                       'number': '9123'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KY', 'icao': 'KNA', 'name': 'Kunming Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': 'KY9473',
#                       'icao': 'KNA9473',
#                       'number': '9473'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CA', 'icao': 'CCA', 'name': 'Air China LTD'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': 'CA3573',
#                       'icao': 'CCA3573',
#                       'number': '3573'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': '3U2625',
#                       'icao': 'CSC2625',
#                       'number': '2625'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': None,
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'YYA',
#                        'icao': 'ZGYY',
#                        'scheduled': '2021-04-22T08:30:00+00:00',
#                        'terminal': None,
#                        'timezone': None},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'EU6671',
#                       'icao': 'UEA6671',
#                       'number': '6671'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Ji An/Jing Gang Shan',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'JGS',
#                        'icao': 'ZSJA',
#                        'scheduled': '2021-04-22T08:45:00+00:00',
#                        'terminal': 'T3',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'EU2735',
#                       'icao': 'UEA2735',
#                       'number': '2735'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Ji An/Jing Gang Shan',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'JGS',
#                        'icao': 'ZSJA',
#                        'scheduled': '2021-04-22T08:45:00+00:00',
#                        'terminal': 'T3',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'eu',
#                                      'airline_icao': 'uea',
#                                      'airline_name': 'chengdu airlines',
#                                      'flight_iata': 'eu2735',
#                                      'flight_icao': 'uea2735',
#                                      'flight_number': '2735'},
#                       'iata': '3U4073',
#                       'icao': 'CSC4073',
#                       'number': '4073'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Weihai',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WEH',
#                        'icao': 'ZSWH',
#                        'scheduled': '2021-04-22T09:55:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'EU2703',
#                       'icao': 'UEA2703',
#                       'number': '2703'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'TV', 'icao': 'TBA', 'name': 'Tibet Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Weihai',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WEH',
#                        'icao': 'ZSWH',
#                        'scheduled': '2021-04-22T09:55:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'eu',
#                                      'airline_icao': 'uea',
#                                      'airline_name': 'chengdu airlines',
#                                      'flight_iata': 'eu2703',
#                                      'flight_icao': 'uea2703',
#                                      'flight_number': '2703'},
#                       'iata': 'TV7139',
#                       'icao': 'TBA7139',
#                       'number': '7139'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Weihai',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WEH',
#                        'icao': 'ZSWH',
#                        'scheduled': '2021-04-22T09:55:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'eu',
#                                      'airline_icao': 'uea',
#                                      'airline_name': 'chengdu airlines',
#                                      'flight_iata': 'eu2703',
#                                      'flight_icao': 'uea2703',
#                                      'flight_number': '2703'},
#                       'iata': '3U4065',
#                       'icao': 'CSC4065',
#                       'number': '4065'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'HO', 'icao': 'DKH', 'name': 'Juneyao Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9566',
#                                      'flight_icao': 'csz9566',
#                                      'flight_number': '9566'},
#                       'iata': 'HO5154',
#                       'icao': 'DKH5154',
#                       'number': '5154'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CZ',
#                        'icao': 'CSN',
#                        'name': 'China Southern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Gonggar/Lhasa',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LXA',
#                        'icao': 'ZULS',
#                        'scheduled': '2021-04-22T09:25:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Chongqing Jiangbei International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CKG',
#                          'icao': 'ZUCK',
#                          'scheduled': '2021-04-22T06:35:00+00:00',
#                          'terminal': 'T2A',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': '3u',
#                                      'airline_icao': 'csc',
#                                      'airline_name': 'sichuan airlines',
#                                      'flight_iata': '3u8633',
#                                      'flight_icao': 'csc8633',
#                                      'flight_number': '8633'},
#                       'iata': 'CZ9367',
#                       'icao': 'CSN9367',
#                       'number': '9367'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EY', 'icao': 'ETD', 'name': 'Etihad Airways'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Kingsford Smith',
#                        'baggage': 'D1',
#                        'delay': None,
#                        'estimated': '2021-04-22T08:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A35',
#                        'iata': 'SYD',
#                        'icao': 'YSSY',
#                        'scheduled': '2021-04-22T08:20:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Australia/Sydney'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adelaide International Airport',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '16',
#                          'iata': 'ADL',
#                          'icao': 'YPAD',
#                          'scheduled': '2021-04-22T06:00:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Australia/Adelaide'},
#            'flight': {'codeshared': {'airline_iata': 'va',
#                                      'airline_icao': 'voz',
#                                      'airline_name': 'virgin australia',
#                                      'flight_iata': 'va401',
#                                      'flight_icao': 'voz401',
#                                      'flight_number': '401'},
#                       'iata': 'EY6511',
#                       'icao': 'ETD6511',
#                       'number': '6511'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '9C', 'icao': 'CQH', 'name': 'Spring Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': None,
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LHW',
#                        'icao': 'ZLLL',
#                        'scheduled': '2021-04-22T09:20:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': None},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Guangzhou Baiyun International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CAN',
#                          'icao': 'ZGGG',
#                          'scheduled': '2021-04-22T06:15:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': '9C6231',
#                       'icao': 'CQH6231',
#                       'number': '6231'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CF',
#                        'icao': 'CYZ',
#                        'name': 'China Postal Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T02:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T02:50:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Kunming',
#                          'delay': None,
#                          'estimated': '2021-04-22T00:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'KMG',
#                          'icao': 'ZPPP',
#                          'scheduled': '2021-04-22T00:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'CF9017',
#                       'icao': 'CYZ9017',
#                       'number': '9017'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': {'iata': 'B77W',
#                         'icao': 'B77W',
#                         'icao24': '8990DB',
#                         'registration': 'B-16712'},
#            'airline': {'iata': 'BR', 'icao': 'EVA', 'name': 'EVA Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': 6,
#                        'estimated': '2021-04-21T21:05:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-21T21:05:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-22T00:40:00+00:00',
#                          'actual_runway': '2021-04-22T00:40:00+00:00',
#                          'airport': 'Taiwan Taoyuan International (Chiang Kai '
#                                     'Shek International)',
#                          'delay': 6,
#                          'estimated': '2021-04-22T00:35:00+00:00',
#                          'estimated_runway': '2021-04-22T00:40:00+00:00',
#                          'gate': None,
#                          'iata': 'TPE',
#                          'icao': 'RCTP',
#                          'scheduled': '2021-04-22T00:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Taipei'},
#            'flight': {'codeshared': None,
#                       'iata': 'BR16',
#                       'icao': 'EVA16',
#                       'number': '16'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': {'altitude': 10058.4,
#                     'direction': 66,
#                     'is_ground': False,
#                     'latitude': 28.05,
#                     'longitude': 131.93,
#                     'speed_horizontal': 1020.45,
#                     'speed_vertical': 0,
#                     'updated': '2021-04-21T17:51:12+00:00'}},
#           {'aircraft': None,
#            'airline': {'iata': 'MU',
#                        'icao': 'CES',
#                        'name': 'China Eastern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tianhe International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:00:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WUH',
#                        'icao': 'ZHHH',
#                        'scheduled': '2021-04-22T09:00:00+00:00',
#                        'terminal': '3',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-22T06:50:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
# ...
#                        'airport': 'Noibai International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'HAN',
#                        'icao': 'VVNB',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': 'T1',
#                        'timezone': 'Asia/Ho_Chi_Minh'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tan Son Nhat International',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '2',
#                          'iata': 'SGN',
#                          'icao': 'VVTS',
#                          'scheduled': '2021-04-22T07:15:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Ho_Chi_Minh'},
#            'flight': {'codeshared': None,
#                       'iata': 'VN6004',
#                       'icao': 'HVN6004',
#                       'number': '6004'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'SQ',
#                        'icao': 'SIA',
#                        'name': 'Singapore Airlines'},
#            'arrival': {'actual': '2021-04-22T06:15:00+00:00',
#                        'actual_runway': '2021-04-22T06:15:00+00:00',
#                        'airport': 'Auckland International',
#                        'baggage': None,
#                        'delay': 6,
#                        'estimated': '2021-04-22T06:10:00+00:00',
#                        'estimated_runway': '2021-04-22T06:15:00+00:00',
#                        'gate': None,
#                        'iata': 'AKL',
#                        'icao': 'NZAA',
#                        'scheduled': '2021-04-22T06:10:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'Pacific/Auckland'},
#            'departure': {'actual': '2021-04-22T01:15:00+00:00',
#                          'actual_runway': '2021-04-22T01:15:00+00:00',
#                          'airport': 'Tullamarine',
#                          'delay': 45,
#                          'estimated': '2021-04-22T00:30:00+00:00',
#                          'estimated_runway': '2021-04-22T01:15:00+00:00',
#                          'gate': None,
#                          'iata': 'MEL',
#                          'icao': 'YMML',
#                          'scheduled': '2021-04-22T00:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Australia/Melbourne'},
#            'flight': {'codeshared': None,
#                       'iata': 'SQ7290',
#                       'icao': 'SIA7290',
#                       'number': '7290'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Seoul (Incheon)',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T17:35:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ICN',
#                        'icao': 'RKSI',
#                        'scheduled': '2021-04-22T17:35:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Seoul'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Arlanda',
#                          'delay': None,
#                          'estimated': '2021-04-22T00:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'ARN',
#                          'icao': 'ESSA',
#                          'scheduled': '2021-04-22T00:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Europe/Stockholm'},
#            'flight': {'codeshared': None,
#                       'iata': 'KE510',
#                       'icao': 'KAL510',
#                       'number': '510'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'JL', 'icao': 'JAL', 'name': 'JAL'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Haneda Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'HND',
#                        'icao': 'RJTT',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'JL606',
#                       'icao': 'JAL606',
#                       'number': '606'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'cancelled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'BC', 'icao': 'SKY', 'name': 'Skymark Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Kobe',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'UKB',
#                        'icao': 'RJBE',
#                        'scheduled': '2021-04-22T08:45:00+00:00',
#                        'terminal': 'D',
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'BC140',
#                       'icao': 'SKY140',
#                       'number': '140'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'BC', 'icao': 'SKY', 'name': 'Skymark Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Haneda Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T10:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'HND',
#                        'icao': 'RJTT',
#                        'scheduled': '2021-04-22T10:25:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'BC440',
#                       'icao': 'SKY440',
#                       'number': '440'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'OC',
#                        'icao': 'ORC',
#                        'name': 'Oriental Air Bridge'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Iki',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'IKI',
#                        'icao': 'RJDB',
#                        'scheduled': '2021-04-22T08:20:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '1',
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'OC41',
#                       'icao': 'ORC41',
#                       'number': '41'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NH', 'icao': 'ANA', 'name': 'ANA'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Iki',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'IKI',
#                        'icao': 'RJDB',
#                        'scheduled': '2021-04-22T08:20:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'NH4641',
#                       'icao': 'ANA4641',
#                       'number': '4641'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NH', 'icao': 'ANA', 'name': 'ANA'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Itami',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ITM',
#                        'icao': 'RJOO',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T08:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T08:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'NH782',
#                       'icao': 'ANA782',
#                       'number': '782'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'cancelled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'OZ', 'icao': 'AAR', 'name': 'Asiana Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Jeju Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:35:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'CJU',
#                        'icao': 'RKPC',
#                        'scheduled': '2021-04-22T08:35:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Seoul'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Gimhae',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PUS',
#                          'icao': 'RKPK',
#                          'scheduled': '2021-04-22T07:20:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'bx',
#                                      'airline_icao': 'abl',
#                                      'airline_name': 'air busan',
#                                      'flight_iata': 'bx8107',
#                                      'flight_icao': 'abl8107',
#                                      'flight_number': '8107'},
#                       'iata': 'OZ8107',
#                       'icao': 'AAR8107',
#                       'number': '8107'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 10730761}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
    'search': 'Atlanta'
}

api_result = requests.get('https://api.aviationstack.com/v1/airports', params)

api_response = api_result.json()

pprint(api_response)
# Out:
# {'data': [{'airport_name': 'Hartsfield-jackson Atlanta International',
#            'city_iata_code': 'ATL',
#            'country_iso2': 'US',
#            'country_name': 'United States',
#            'geoname_id': '4180439',
#            'gmt': '-5',
#            'iata_code': 'ATL',
#            'icao_code': 'KATL',
#            'latitude': '33.640068',
#            'longitude': '-84.44403',
#            'phone_number': '800-897-1910',
#            'timezone': 'America/New_York'}],
#  'pagination': {'count': 1, 'limit': 100, 'offset': 0, 'total': 1}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
    'search': '2019-12-25'
}

api_result = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'EK', 'icao': 'UAE', 'name': 'Emirates'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tullamarine',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:40:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '4',
#                        'iata': 'MEL',
#                        'icao': 'YMML',
#                        'scheduled': '2021-04-22T08:40:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Australia/Melbourne'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Brisbane International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '19',
#                          'iata': 'BNE',
#                          'icao': 'YBBN',
#                          'scheduled': '2021-04-22T06:15:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Brisbane'},
#            'flight': {'codeshared': {'airline_iata': 'qf',
#                                      'airline_icao': 'qfa',
#                                      'airline_name': 'qantas',
#                                      'flight_iata': 'qf605',
#                                      'flight_icao': 'qfa605',
#                                      'flight_number': '605'},
#                       'iata': 'EK5605',
#                       'icao': 'UAE5605',
#                       'number': '5605'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'JQ', 'icao': 'JST', 'name': 'Jetstar'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Cairns',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'CNS',
#                        'icao': 'YBCS',
#                        'scheduled': '2021-04-22T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Australia/Brisbane'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Brisbane International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:10:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '28',
#                          'iata': 'BNE',
#                          'icao': 'YBBN',
#                          'scheduled': '2021-04-22T06:10:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Brisbane'},
#            'flight': {'codeshared': None,
#                       'iata': 'JQ928',
#                       'icao': 'JST928',
#                       'number': '928'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Dali',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:01:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'DLU',
#                        'icao': 'ZPDL',
#                        'scheduled': '2021-04-22T08:01:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'P',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'tv',
#                                      'airline_icao': 'tba',
#                                      'airline_name': 'tibet airlines',
#                                      'flight_iata': 'tv9915',
#                                      'flight_icao': 'tba9915',
#                                      'flight_number': '9915'},
#                       'iata': 'EU7257',
#                       'icao': 'UEA7257',
#                       'number': '7257'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'QB', 'icao': 'QSM', 'name': 'Qeshm Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Al-Ashraf International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T01:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NJF',
#                        'icao': 'ORNI',
#                        'scheduled': '2021-04-22T01:30:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Baghdad'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Mashad',
#                          'delay': None,
#                          'estimated': '2021-04-22T00:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'MHD',
#                          'icao': 'OIMM',
#                          'scheduled': '2021-04-22T00:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tehran'},
#            'flight': {'codeshared': None,
#                       'iata': 'QB2297',
#                       'icao': 'QSM2297',
#                       'number': '2297'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'QF', 'icao': 'QFA', 'name': 'Qantas'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tullamarine',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T07:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '22',
#                        'iata': 'MEL',
#                        'icao': 'YMML',
#                        'scheduled': '2021-04-22T07:15:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Australia/Melbourne'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hobart',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'HBA',
#                          'icao': 'YMHB',
#                          'scheduled': '2021-04-22T06:00:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Hobart'},
#            'flight': {'codeshared': None,
#                       'iata': 'QF1550',
#                       'icao': 'QFA1550',
#                       'number': '1550'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NZ', 'icao': 'ANZ', 'name': 'Air New Zealand'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tullamarine',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T07:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '22',
#                        'iata': 'MEL',
#                        'icao': 'YMML',
#                        'scheduled': '2021-04-22T07:15:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Australia/Melbourne'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hobart',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'HBA',
#                          'icao': 'YMHB',
#                          'scheduled': '2021-04-22T06:00:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Australia/Hobart'},
#            'flight': {'codeshared': {'airline_iata': 'qf',
#                                      'airline_icao': 'qfa',
#                                      'airline_name': 'qantas',
#                                      'flight_iata': 'qf1550',
#                                      'flight_icao': 'qfa1550',
#                                      'flight_number': '1550'},
#                       'iata': 'NZ7361',
#                       'icao': 'ANZ7361',
#                       'number': '7361'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'HT', 'icao': 'HAT', 'name': 'Air Horizont'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Zhengzhou',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T05:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'CGO',
#                        'icao': 'ZHCC',
#                        'scheduled': '2021-04-22T05:25:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nanchang',
#                          'delay': None,
#                          'estimated': '2021-04-22T03:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'KHN',
#                          'icao': 'ZSCN',
#                          'scheduled': '2021-04-22T03:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'HT3810',
#                       'icao': 'HAT3810',
#                       'number': '3810'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CA', 'icao': 'CCA', 'name': 'Air China LTD'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9566',
#                                      'flight_icao': 'csz9566',
#                                      'flight_number': '9566'},
#                       'iata': 'CA3866',
#                       'icao': 'CCA3866',
#                       'number': '3866'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9566',
#                                      'flight_icao': 'csz9566',
#                                      'flight_number': '9566'},
#                       'iata': '3U2648',
#                       'icao': 'CSC2648',
#                       'number': '2648'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'ZH',
#                        'icao': 'CSZ',
#                        'name': 'Shenzhen Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'ZH9473',
#                       'icao': 'CSZ9473',
#                       'number': '9473'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'SC',
#                        'icao': 'CDG',
#                        'name': 'Shandong Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': 'SC9123',
#                       'icao': 'CDG9123',
#                       'number': '9123'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KY', 'icao': 'KNA', 'name': 'Kunming Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': 'KY9473',
#                       'icao': 'KNA9473',
#                       'number': '9473'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CA', 'icao': 'CCA', 'name': 'Air China LTD'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': 'CA3573',
#                       'icao': 'CCA3573',
#                       'number': '3573'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanchang',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'KHN',
#                        'icao': 'ZSCN',
#                        'scheduled': '2021-04-22T08:55:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9473',
#                                      'flight_icao': 'csz9473',
#                                      'flight_number': '9473'},
#                       'iata': '3U2625',
#                       'icao': 'CSC2625',
#                       'number': '2625'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': None,
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'YYA',
#                        'icao': 'ZGYY',
#                        'scheduled': '2021-04-22T08:30:00+00:00',
#                        'terminal': None,
#                        'timezone': None},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'EU6671',
#                       'icao': 'UEA6671',
#                       'number': '6671'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Ji An/Jing Gang Shan',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'JGS',
#                        'icao': 'ZSJA',
#                        'scheduled': '2021-04-22T08:45:00+00:00',
#                        'terminal': 'T3',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'EU2735',
#                       'icao': 'UEA2735',
#                       'number': '2735'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Ji An/Jing Gang Shan',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'JGS',
#                        'icao': 'ZSJA',
#                        'scheduled': '2021-04-22T08:45:00+00:00',
#                        'terminal': 'T3',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'eu',
#                                      'airline_icao': 'uea',
#                                      'airline_name': 'chengdu airlines',
#                                      'flight_iata': 'eu2735',
#                                      'flight_icao': 'uea2735',
#                                      'flight_number': '2735'},
#                       'iata': '3U4073',
#                       'icao': 'CSC4073',
#                       'number': '4073'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EU', 'icao': 'UEA', 'name': 'Chengdu Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Weihai',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WEH',
#                        'icao': 'ZSWH',
#                        'scheduled': '2021-04-22T09:55:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'EU2703',
#                       'icao': 'UEA2703',
#                       'number': '2703'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'TV', 'icao': 'TBA', 'name': 'Tibet Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Weihai',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WEH',
#                        'icao': 'ZSWH',
#                        'scheduled': '2021-04-22T09:55:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'eu',
#                                      'airline_icao': 'uea',
#                                      'airline_name': 'chengdu airlines',
#                                      'flight_iata': 'eu2703',
#                                      'flight_icao': 'uea2703',
#                                      'flight_number': '2703'},
#                       'iata': 'TV7139',
#                       'icao': 'TBA7139',
#                       'number': '7139'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '3U', 'icao': 'CSC', 'name': 'Sichuan Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Weihai',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WEH',
#                        'icao': 'ZSWH',
#                        'scheduled': '2021-04-22T09:55:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H,J',
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'eu',
#                                      'airline_icao': 'uea',
#                                      'airline_name': 'chengdu airlines',
#                                      'flight_iata': 'eu2703',
#                                      'flight_icao': 'uea2703',
#                                      'flight_number': '2703'},
#                       'iata': '3U4065',
#                       'icao': 'CSC4065',
#                       'number': '4065'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'HO', 'icao': 'DKH', 'name': 'Juneyao Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shuangliu',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CTU',
#                          'icao': 'ZUUU',
#                          'scheduled': '2021-04-22T06:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': 'zh',
#                                      'airline_icao': 'csz',
#                                      'airline_name': 'shenzhen airlines',
#                                      'flight_iata': 'zh9566',
#                                      'flight_icao': 'csz9566',
#                                      'flight_number': '9566'},
#                       'iata': 'HO5154',
#                       'icao': 'DKH5154',
#                       'number': '5154'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CZ',
#                        'icao': 'CSN',
#                        'name': 'China Southern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Gonggar/Lhasa',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LXA',
#                        'icao': 'ZULS',
#                        'scheduled': '2021-04-22T09:25:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Chongqing Jiangbei International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CKG',
#                          'icao': 'ZUCK',
#                          'scheduled': '2021-04-22T06:35:00+00:00',
#                          'terminal': 'T2A',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': {'airline_iata': '3u',
#                                      'airline_icao': 'csc',
#                                      'airline_name': 'sichuan airlines',
#                                      'flight_iata': '3u8633',
#                                      'flight_icao': 'csc8633',
#                                      'flight_number': '8633'},
#                       'iata': 'CZ9367',
#                       'icao': 'CSN9367',
#                       'number': '9367'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'EY', 'icao': 'ETD', 'name': 'Etihad Airways'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Kingsford Smith',
#                        'baggage': 'D1',
#                        'delay': None,
#                        'estimated': '2021-04-22T08:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A35',
#                        'iata': 'SYD',
#                        'icao': 'YSSY',
#                        'scheduled': '2021-04-22T08:20:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Australia/Sydney'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adelaide International Airport',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '16',
#                          'iata': 'ADL',
#                          'icao': 'YPAD',
#                          'scheduled': '2021-04-22T06:00:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Australia/Adelaide'},
#            'flight': {'codeshared': {'airline_iata': 'va',
#                                      'airline_icao': 'voz',
#                                      'airline_name': 'virgin australia',
#                                      'flight_iata': 'va401',
#                                      'flight_icao': 'voz401',
#                                      'flight_number': '401'},
#                       'iata': 'EY6511',
#                       'icao': 'ETD6511',
#                       'number': '6511'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': '9C', 'icao': 'CQH', 'name': 'Spring Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': None,
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LHW',
#                        'icao': 'ZLLL',
#                        'scheduled': '2021-04-22T09:20:00+00:00',
#                        'terminal': 'T2',
#                        'timezone': None},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Guangzhou Baiyun International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'CAN',
#                          'icao': 'ZGGG',
#                          'scheduled': '2021-04-22T06:15:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': '9C6231',
#                       'icao': 'CQH6231',
#                       'number': '6231'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CF',
#                        'icao': 'CYZ',
#                        'name': 'China Postal Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Nanjing Lukou International Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T02:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'NKG',
#                        'icao': 'ZSNJ',
#                        'scheduled': '2021-04-22T02:50:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Kunming',
#                          'delay': None,
#                          'estimated': '2021-04-22T00:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'KMG',
#                          'icao': 'ZPPP',
#                          'scheduled': '2021-04-22T00:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'CF9017',
#                       'icao': 'CYZ9017',
#                       'number': '9017'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': {'iata': 'B77W',
#                         'icao': 'B77W',
#                         'icao24': '8990DB',
#                         'registration': 'B-16712'},
#            'airline': {'iata': 'BR', 'icao': 'EVA', 'name': 'EVA Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': 6,
#                        'estimated': '2021-04-21T21:05:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-21T21:05:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-22T00:40:00+00:00',
#                          'actual_runway': '2021-04-22T00:40:00+00:00',
#                          'airport': 'Taiwan Taoyuan International (Chiang Kai '
#                                     'Shek International)',
#                          'delay': 6,
#                          'estimated': '2021-04-22T00:35:00+00:00',
#                          'estimated_runway': '2021-04-22T00:40:00+00:00',
#                          'gate': None,
#                          'iata': 'TPE',
#                          'icao': 'RCTP',
#                          'scheduled': '2021-04-22T00:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Taipei'},
#            'flight': {'codeshared': None,
#                       'iata': 'BR16',
#                       'icao': 'EVA16',
#                       'number': '16'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': {'altitude': 10058.4,
#                     'direction': 66,
#                     'is_ground': False,
#                     'latitude': 28.05,
#                     'longitude': 131.93,
#                     'speed_horizontal': 1020.45,
#                     'speed_vertical': 0,
#                     'updated': '2021-04-21T17:51:12+00:00'}},
#           {'aircraft': None,
#            'airline': {'iata': 'MU',
#                        'icao': 'CES',
#                        'name': 'China Eastern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Tianhe International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:00:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'WUH',
#                        'icao': 'ZHHH',
#                        'scheduled': '2021-04-22T09:00:00+00:00',
#                        'terminal': '3',
#                        'timezone': 'Asia/Shanghai'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': None,
#                          'estimated': '2021-04-22T06:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-22T06:50:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
# ...
#                        'airport': 'Noibai International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'HAN',
#                        'icao': 'VVNB',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': 'T1',
#                        'timezone': 'Asia/Ho_Chi_Minh'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tan Son Nhat International',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '2',
#                          'iata': 'SGN',
#                          'icao': 'VVTS',
#                          'scheduled': '2021-04-22T07:15:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Ho_Chi_Minh'},
#            'flight': {'codeshared': None,
#                       'iata': 'VN6004',
#                       'icao': 'HVN6004',
#                       'number': '6004'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'SQ',
#                        'icao': 'SIA',
#                        'name': 'Singapore Airlines'},
#            'arrival': {'actual': '2021-04-22T06:15:00+00:00',
#                        'actual_runway': '2021-04-22T06:15:00+00:00',
#                        'airport': 'Auckland International',
#                        'baggage': None,
#                        'delay': 2,
#                        'estimated': '2021-04-22T06:10:00+00:00',
#                        'estimated_runway': '2021-04-22T06:15:00+00:00',
#                        'gate': None,
#                        'iata': 'AKL',
#                        'icao': 'NZAA',
#                        'scheduled': '2021-04-22T06:10:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'Pacific/Auckland'},
#            'departure': {'actual': '2021-04-22T01:15:00+00:00',
#                          'actual_runway': '2021-04-22T01:15:00+00:00',
#                          'airport': 'Tullamarine',
#                          'delay': 45,
#                          'estimated': '2021-04-22T00:30:00+00:00',
#                          'estimated_runway': '2021-04-22T01:15:00+00:00',
#                          'gate': None,
#                          'iata': 'MEL',
#                          'icao': 'YMML',
#                          'scheduled': '2021-04-22T00:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Australia/Melbourne'},
#            'flight': {'codeshared': None,
#                       'iata': 'SQ7290',
#                       'icao': 'SIA7290',
#                       'number': '7290'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Seoul (Incheon)',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T17:35:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ICN',
#                        'icao': 'RKSI',
#                        'scheduled': '2021-04-22T17:35:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Seoul'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Arlanda',
#                          'delay': None,
#                          'estimated': '2021-04-22T00:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'ARN',
#                          'icao': 'ESSA',
#                          'scheduled': '2021-04-22T00:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Europe/Stockholm'},
#            'flight': {'codeshared': None,
#                       'iata': 'KE510',
#                       'icao': 'KAL510',
#                       'number': '510'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'JL', 'icao': 'JAL', 'name': 'JAL'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Haneda Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'HND',
#                        'icao': 'RJTT',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'JL606',
#                       'icao': 'JAL606',
#                       'number': '606'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'cancelled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'BC', 'icao': 'SKY', 'name': 'Skymark Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Kobe',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'UKB',
#                        'icao': 'RJBE',
#                        'scheduled': '2021-04-22T08:45:00+00:00',
#                        'terminal': 'D',
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'BC140',
#                       'icao': 'SKY140',
#                       'number': '140'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'BC', 'icao': 'SKY', 'name': 'Skymark Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Haneda Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T10:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'HND',
#                        'icao': 'RJTT',
#                        'scheduled': '2021-04-22T10:25:00+00:00',
#                        'terminal': '1',
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:40:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'BC440',
#                       'icao': 'SKY440',
#                       'number': '440'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'OC',
#                        'icao': 'ORC',
#                        'name': 'Oriental Air Bridge'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Iki',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'IKI',
#                        'icao': 'RJDB',
#                        'scheduled': '2021-04-22T08:20:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '1',
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'OC41',
#                       'icao': 'ORC41',
#                       'number': '41'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NH', 'icao': 'ANA', 'name': 'ANA'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Iki',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:20:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'IKI',
#                        'icao': 'RJDB',
#                        'scheduled': '2021-04-22T08:20:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T07:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'NH4641',
#                       'icao': 'ANA4641',
#                       'number': '4641'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NH', 'icao': 'ANA', 'name': 'ANA'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Itami',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T09:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ITM',
#                        'icao': 'RJOO',
#                        'scheduled': '2021-04-22T09:15:00+00:00',
#                        'terminal': None,
#                        'timezone': 'Asia/Tokyo'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nagasaki',
#                          'delay': None,
#                          'estimated': '2021-04-22T08:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NGS',
#                          'icao': 'RJFU',
#                          'scheduled': '2021-04-22T08:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Tokyo'},
#            'flight': {'codeshared': None,
#                       'iata': 'NH782',
#                       'icao': 'ANA782',
#                       'number': '782'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'cancelled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'OZ', 'icao': 'AAR', 'name': 'Asiana Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Jeju Airport',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T08:35:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'CJU',
#                        'icao': 'RKPC',
#                        'scheduled': '2021-04-22T08:35:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'Asia/Seoul'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Gimhae',
#                          'delay': None,
#                          'estimated': '2021-04-22T07:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PUS',
#                          'icao': 'RKPK',
#                          'scheduled': '2021-04-22T07:20:00+00:00',
#                          'terminal': 'D',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'bx',
#                                      'airline_icao': 'abl',
#                                      'airline_name': 'air busan',
#                                      'flight_iata': 'bx8107',
#                                      'flight_icao': 'abl8107',
#                                      'flight_number': '8107'},
#                       'iata': 'OZ8107',
#                       'icao': 'AAR8107',
#                       'number': '8107'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'scheduled',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 10731364}}
